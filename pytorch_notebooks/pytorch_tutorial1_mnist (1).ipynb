# %%
# Create a range of input values
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
x_values = torch.linspace(-5, 5, steps=200)

# Apply activation functions
relu_values = nn.ReLU()(x_values)
tanh_values = nn.Tanh()(x_values)
sigmoid_values = nn.Sigmoid()(x_values)

# Plot them
plt.figure(figsize=(8, 6))
plt.plot(x_values.numpy(), relu_values.numpy(), label='ReLU')

plt.figure(figsize=(8, 6))

plt.plot(x_values.numpy(), tanh_values.numpy(), label='Tanh')
plt.figure(figsize=(8, 6))
plt.plot(x_values.numpy(), sigmoid_values.numpy(), label='Sigmoid')
plt.axhline(0, color='black', linewidth=0.5)
plt.legend()
plt.title("Activation Functions")
plt.show()

# Comments:
# ReLU: Used for many neural networks to avoid the vanishing gradient problem.
# Tanh: Outputs values between -1 and 1, often used to center data around zero.
# Sigmoid: Outputs values between 0 and 1, often used in binary classification.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# Define the linear regression model
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        # self.linear = nn.Linear(1, 1)  # One input feature and one output
        # make it good for exponential function
        self.linear = nn.Linear(1, 1, bias=False)  # One input feature and one output
        # in equations terms this woudl be y = w*x
        # now add a non-linearity
        self.non_linearity = nn.ReLU()
        # add a sigmoid
        # self.non_linearity = nn.Sigmoid()
        


    def forward(self, x):
        return self.linear(x)
        # return self.non_linearity(self.linear(x))
        
        
        
        

# Generate synthetic data
n_points = 1000
x = torch.randn(n_points, 1) * 2  # Input features
y = 2 * x + 3 + torch.randn(n_points, 1) * 0.5  # Output with noise

# Create model and optimizer
model = LinearRegression()
optimizer = optim.SGD(model.parameters(), lr=0.005)

# Training loop
num_epochs = 300
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(x)
    loss = nn.MSELoss()(outputs, y)
    # try with nn.L1Loss() or nn.SmoothL1Loss()

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")

# Plot predictions vs true values
predicted = model(x).detach().numpy()
plt.scatter(x.numpy(), y.numpy(), label='True')
plt.scatter(x.numpy(), predicted, color='red', label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch [10/300], Loss: 17.2901
# Epoch [20/300], Loss: 12.9347
# Epoch [30/300], Loss: 10.9801
# Epoch [40/300], Loss: 10.1029
# Epoch [50/300], Loss: 9.7092
# Epoch [60/300], Loss: 9.5326
# Epoch [70/300], Loss: 9.4533
# Epoch [80/300], Loss: 9.4177
# Epoch [90/300], Loss: 9.4017
# Epoch [100/300], Loss: 9.3946
# Epoch [110/300], Loss: 9.3914
# Epoch [120/300], Loss: 9.3899
# Epoch [130/300], Loss: 9.3893
# Epoch [140/300], Loss: 9.3890
# Epoch [150/300], Loss: 9.3889
# Epoch [160/300], Loss: 9.3888
# Epoch [170/300], Loss: 9.3888
# Epoch [180/300], Loss: 9.3888
# Epoch [190/300], Loss: 9.3888
# Epoch [200/300], Loss: 9.3887
# Epoch [210/300], Loss: 9.3887
# Epoch [220/300], Loss: 9.3887
# Epoch [230/300], Loss: 9.3887
# Epoch [240/300], Loss: 9.3887
# Epoch [250/300], Loss: 9.3887
# Epoch [260/300], Loss: 9.3887
# Epoch [270/300], Loss: 9.3887
# Epoch [280/300], Loss: 9.3887
# Epoch [290/300], Loss: 9.3887
# Epoch [300/300], Loss: 9.3887

# %% [markdown]
# 2. Build a multi-layer perceptron (MLP) for classification
#    - Create an nn.Module class that defines an MLP architecture with configurable hidden layer sizes
#    - Load a classification dataset (e.g. MNIST handwritten digits) using PyTorch's datasets and DataLoader
#    - Define a training loop that performs forward pass, computes cross-entropy loss, performs backpropagation, and updates weights
#    - Evaluate the trained model on a test set and report accuracy

# %%
import matplotlib.pyplot as plt
import torchvision

# Load MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=torchvision.transforms.ToTensor(), download=True)

# Plot the first 9 images
fig, axes = plt.subplots(3, 3, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    image, label = train_dataset[i]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"Label: {label}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /opt/homebrew/anaconda3/envs/llm2/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/opt/homebrew/anaconda3/envs/llm2/lib/python3.10/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <EA7F9DF5-8854-31D8-89D4-BD566CAF4DEA> /opt/homebrew/anaconda3/envs/llm2/lib/python3.10/site-packages/torchvision/image.so
#   Expected in:     <ECC148AF-20FF-3EEE-BC75-4DD3E7455393> /opt/homebrew/anaconda3/envs/llm2/lib/python3.10/site-packages/torch/lib/libtorch_cpu.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# Define the MLP model with configurable activation function
class MLP(nn.Module):
    def __init__(self, hidden_sizes, activation):
        super(MLP, self).__init__()
        self.hidden_layers = nn.ModuleList()
        input_size = 784  # 28x28 flattened MNIST images
        for hidden_size in hidden_sizes:
            self.hidden_layers.append(nn.Linear(input_size, hidden_size))
            self.hidden_layers.append(activation)
            input_size = hidden_size
        self.output_layer = nn.Linear(input_size, 10)  # 10 classes for MNIST

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input
        activations = []
        for layer in self.hidden_layers:
            x = layer(x)
            activations.append(x)
        output = self.output_layer(x)
        return output, activations

# Load MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# Define activation functions to compare
activations_func = [nn.ReLU(), nn.Tanh(), nn.Sigmoid()]

# Train and evaluate models with different activation functions
for activation in activations_func:
    model = MLP(hidden_sizes=[128, 64], activation=activation)
    optimizer = optim.Adam(model.parameters())

    # Training loop
    num_epochs = 5
    for epoch in range(num_epochs):
        for images, labels in train_loader:
            # Forward pass
            outputs, _ = model(images)
            loss = nn.CrossEntropyLoss()(outputs, labels)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Evaluate on test set
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            outputs, activations = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
        print(f"Activation: {activation.__class__.__name__}, Test Accuracy: {accuracy:.2f}%")

    # Visualize activations
    plt.figure(figsize=(12, 4))
    for i, activation in enumerate(activations):
        plt.subplot(1, len(activations), i+1)
        plt.hist(activation.view(-1).numpy(), bins=50)
        plt.title(f"Layer {i+1} Activations")
    plt.tight_layout()
    plt.show()
# Out:
# Activation: ReLU, Test Accuracy: 97.50%
# Activation: Tanh, Test Accuracy: 97.41%
# Activation: Sigmoid, Test Accuracy: 96.86%

# %%
plt.plot(outputs[0].detach().numpy())

# %%
model
# Out:
# MLP(
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): Sigmoid()
#   )
#   (output_layer): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

# Define the MLP model
class MLP(nn.Module):
    def __init__(self, hidden_sizes):
        super(MLP, self).__init__()
        self.hidden_layers = nn.ModuleList()
        input_size = 784  # 28x28 flattened MNIST images
        for hidden_size in hidden_sizes:
            self.hidden_layers.append(nn.Linear(input_size, hidden_size))
            self.hidden_layers.append(nn.ReLU())
            input_size = hidden_size
        self.output_layer = nn.Linear(input_size, 10)  # 10 classes for MNIST

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input
        for layer in self.hidden_layers:
            x = layer(x)
        return self.output_layer(x)

# Load MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# Create model and optimizer
model = MLP(hidden_sizes=[128, 64])
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)  # Learning rate scheduling

# Training loop
num_epochs = 20
best_accuracy = 0.0
for epoch in range(num_epochs):
    for images, labels in train_loader:
        # Forward pass
        outputs = model(images)
        loss = nn.CrossEntropyLoss()(outputs, labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Print gradients of model parameters
    for name, param in model.named_parameters():
        print(f"Gradient of {name}: {param.grad.norm():.4f}")

    # Evaluate on test set
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
        print(f"Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {accuracy:.2f}%")

        # Save the best model checkpoint
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save(model.state_dict(), 'best_model.pth')

    model.train()
    scheduler.step()  # Update learning rate
# Out:
# Gradient of hidden_layers.0.weight: 0.7805
# Gradient of hidden_layers.0.bias: 0.1016
# Gradient of hidden_layers.2.weight: 0.5305
# Gradient of hidden_layers.2.bias: 0.0689
# Gradient of output_layer.weight: 0.4940
# Gradient of output_layer.bias: 0.0441
# Epoch [1/20], Test Accuracy: 93.28%
# Gradient of hidden_layers.0.weight: 0.8991
# Gradient of hidden_layers.0.bias: 0.1323
# Gradient of hidden_layers.2.weight: 0.4669
# Gradient of hidden_layers.2.bias: 0.0851
# Gradient of output_layer.weight: 0.3210
# Gradient of output_layer.bias: 0.0448
# Epoch [2/20], Test Accuracy: 95.44%
# Gradient of hidden_layers.0.weight: 1.8666
# Gradient of hidden_layers.0.bias: 0.2393
# Gradient of hidden_layers.2.weight: 1.2400
# Gradient of hidden_layers.2.bias: 0.1757
# Gradient of output_layer.weight: 1.0413
# Gradient of output_layer.bias: 0.0929
# Epoch [3/20], Test Accuracy: 96.40%
# Gradient of hidden_layers.0.weight: 0.2497
# Gradient of hidden_layers.0.bias: 0.0317
# Gradient of hidden_layers.2.weight: 0.1284
# Gradient of hidden_layers.2.bias: 0.0238
# Gradient of output_layer.weight: 0.0997
# Gradient of output_layer.bias: 0.0123
# Epoch [4/20], Test Accuracy: 96.80%
# Gradient of hidden_layers.0.weight: 0.9225
# Gradient of hidden_layers.0.bias: 0.0862
# Gradient of hidden_layers.2.weight: 0.5289
# Gradient of hidden_layers.2.bias: 0.0653
# Gradient of output_layer.weight: 0.3051
# Gradient of output_layer.bias: 0.0313
# Epoch [5/20], Test Accuracy: 96.51%
# Gradient of hidden_layers.0.weight: 1.5937
# Gradient of hidden_layers.0.bias: 0.1460
# Gradient of hidden_layers.2.weight: 0.6732
# Gradient of hidden_layers.2.bias: 0.0870
# Gradient of output_layer.weight: 0.3914
# Gradient of output_layer.bias: 0.0371
# Epoch [6/20], Test Accuracy: 97.59%
# Gradient of hidden_layers.0.weight: 0.4278
# Gradient of hidden_layers.0.bias: 0.0529
# Gradient of hidden_layers.2.weight: 0.2560
# Gradient of hidden_layers.2.bias: 0.0357
# Gradient of output_layer.weight: 0.1641
# Gradient of output_layer.bias: 0.0153
# Epoch [7/20], Test Accuracy: 97.50%
# Gradient of hidden_layers.0.weight: 1.9395
# Gradient of hidden_layers.0.bias: 0.1739
# Gradient of hidden_layers.2.weight: 1.0312
# Gradient of hidden_layers.2.bias: 0.1083
# Gradient of output_layer.weight: 0.6684
# Gradient of output_layer.bias: 0.0472
# Epoch [8/20], Test Accuracy: 97.57%
# Gradient of hidden_layers.0.weight: 1.1553
# Gradient of hidden_layers.0.bias: 0.1858
# Gradient of hidden_layers.2.weight: 0.6970
# Gradient of hidden_layers.2.bias: 0.1247
# Gradient of output_layer.weight: 0.4703
# Gradient of output_layer.bias: 0.0578
# Epoch [9/20], Test Accuracy: 97.54%
# Gradient of hidden_layers.0.weight: 0.3743
# Gradient of hidden_layers.0.bias: 0.0433
# Gradient of hidden_layers.2.weight: 0.1633
# Gradient of hidden_layers.2.bias: 0.0252
# Gradient of output_layer.weight: 0.0909
# Gradient of output_layer.bias: 0.0110
# Epoch [10/20], Test Accuracy: 97.52%
# Gradient of hidden_layers.0.weight: 1.1714
# Gradient of hidden_layers.0.bias: 0.1463
# Gradient of hidden_layers.2.weight: 0.6806
# Gradient of hidden_layers.2.bias: 0.0889
# Gradient of output_layer.weight: 0.4668
# Gradient of output_layer.bias: 0.0421
# Epoch [11/20], Test Accuracy: 97.61%
# Gradient of hidden_layers.0.weight: 0.1292
# Gradient of hidden_layers.0.bias: 0.0141
# Gradient of hidden_layers.2.weight: 0.0551
# Gradient of hidden_layers.2.bias: 0.0059
# Gradient of output_layer.weight: 0.0310
# Gradient of output_layer.bias: 0.0027
# Epoch [12/20], Test Accuracy: 97.61%
# Gradient of hidden_layers.0.weight: 0.2513
# Gradient of hidden_layers.0.bias: 0.0298
# Gradient of hidden_layers.2.weight: 0.1324
# Gradient of hidden_layers.2.bias: 0.0180
# Gradient of output_layer.weight: 0.1004
# Gradient of output_layer.bias: 0.0091
# Epoch [13/20], Test Accuracy: 97.63%
# Gradient of hidden_layers.0.weight: 1.0036
# Gradient of hidden_layers.0.bias: 0.0795
# Gradient of hidden_layers.2.weight: 0.7778
# Gradient of hidden_layers.2.bias: 0.0539
# Gradient of output_layer.weight: 0.4889
# Gradient of output_layer.bias: 0.0282
# Epoch [14/20], Test Accuracy: 97.61%
# Gradient of hidden_layers.0.weight: 0.7238
# Gradient of hidden_layers.0.bias: 0.0769
# Gradient of hidden_layers.2.weight: 0.4241
# Gradient of hidden_layers.2.bias: 0.0467
# Gradient of output_layer.weight: 0.3180
# Gradient of output_layer.bias: 0.0221
# Epoch [15/20], Test Accuracy: 97.63%
# Gradient of hidden_layers.0.weight: 0.8486
# Gradient of hidden_layers.0.bias: 0.1049
# Gradient of hidden_layers.2.weight: 0.3676
# Gradient of hidden_layers.2.bias: 0.0612
# Gradient of output_layer.weight: 0.2437
# Gradient of output_layer.bias: 0.0278
# Epoch [16/20], Test Accuracy: 97.64%
# Gradient of hidden_layers.0.weight: 0.6811
# Gradient of hidden_layers.0.bias: 0.0766
# Gradient of hidden_layers.2.weight: 0.2979
# Gradient of hidden_layers.2.bias: 0.0513
# Gradient of output_layer.weight: 0.1889
# Gradient of output_layer.bias: 0.0237
# Epoch [17/20], Test Accuracy: 97.64%
# Gradient of hidden_layers.0.weight: 0.1300
# Gradient of hidden_layers.0.bias: 0.0176
# Gradient of hidden_layers.2.weight: 0.0742
# Gradient of hidden_layers.2.bias: 0.0105
# Gradient of output_layer.weight: 0.0559
# Gradient of output_layer.bias: 0.0057
# Epoch [18/20], Test Accuracy: 97.63%
# Gradient of hidden_layers.0.weight: 0.0888
# Gradient of hidden_layers.0.bias: 0.0105
# Gradient of hidden_layers.2.weight: 0.0408
# Gradient of hidden_layers.2.bias: 0.0059
# Gradient of output_layer.weight: 0.0246
# Gradient of output_layer.bias: 0.0026
# Epoch [19/20], Test Accuracy: 97.62%
# Gradient of hidden_layers.0.weight: 0.0716
# Gradient of hidden_layers.0.bias: 0.0093
# Gradient of hidden_layers.2.weight: 0.0286
# Gradient of hidden_layers.2.bias: 0.0047
# Gradient of output_layer.weight: 0.0180
# Gradient of output_layer.bias: 0.0019
# Epoch [20/20], Test Accuracy: 97.62%
